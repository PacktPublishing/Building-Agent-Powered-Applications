# %% [markdown]
# ### Language detection

# %%
import fasttext

model = fasttext.load_model("lid.176.bin")
text = "Bonjour, comment allez-vous ?"
lang = model.predict(text, k=1)  # returns language code like '__label__fr'

# %%
SELECT SUM(amount)
FROM transactions
WHERE customer_id = 'C001'
  AND category = 'Travel'
  AND date BETWEEN '2023-01-01' AND '2023-12-31';
