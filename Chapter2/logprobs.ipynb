# %%
POST https://api.openai.com/v1/completions

{
  "model": "text-davinci-003",
  "prompt": "The capital of France is",
  "max_tokens": 5,
  "logprobs": 5,
  "temperature": 0.7
}

# %%
{
  "choices": [
    {
      "text": " Paris",
      "logprobs": {
        "tokens": [" Paris"],
        "token_logprobs": [-0.105],
        "top_logprobs": [
          {
            " Paris": -0.105,
            " Lyon": -2.7,
            " Marseille": -3.2,
            ...
          }
        ],
        ...
      }
    }
  ]
}
